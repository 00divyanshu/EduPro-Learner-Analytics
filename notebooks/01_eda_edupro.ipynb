# %% [markdown]
# # EduPro Learner Analytics EDA
#
# This notebook runs the same reusable pipeline used by the dashboard, then explores demographics, course popularity, and enrollment behavior.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.data_ingestion import load_config
from src.eda import run_pipeline
from src.kpi_metrics import calculate_kpis
from src.insights import generate_business_insights, generate_recommendations

config = load_config(ROOT / 'config' / 'config.yaml')
outputs = run_pipeline(config, save_outputs=True)
master_df = outputs['master']
master_df.head()

# %%
calculate_kpis(master_df)

# %%
master_df.groupby('AgeGroup')['TransactionID'].nunique().sort_values(ascending=False)

# %%
master_df.groupby(['Gender', 'CourseLevel'])['TransactionID'].nunique().unstack(fill_value=0)

# %%
generate_business_insights(master_df), generate_recommendations(master_df)
